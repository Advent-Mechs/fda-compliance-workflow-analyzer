# %%
import pandas as pd

df = pd.read_csv('../data/raw/CountryProductResidueData2023.txt', 
                  quotechar='"', 
                  on_bad_lines='warn')
df.shape
# Out:
# /var/folders/fg/z4qqyj7j6v1fp2jr2444yqmm0000gn/T/ipykernel_84906/3017584838.py:3: ParserWarning: Skipping line 807: expected 4 fields, saw 5
# Skipping line 1563: expected 4 fields, saw 5
# Skipping line 1612: expected 4 fields, saw 5
# Skipping line 2368: expected 4 fields, saw 5
# Skipping line 2417: expected 4 fields, saw 6
# Skipping line 2418: expected 4 fields, saw 5
# Skipping line 2625: expected 4 fields, saw 5
# Skipping line 2626: expected 4 fields, saw 5
# Skipping line 3174: expected 4 fields, saw 6
# Skipping line 4817: expected 4 fields, saw 5
# Skipping line 5578: expected 4 fields, saw 5
# Skipping line 5627: expected 4 fields, saw 5
# Skipping line 6367: expected 4 fields, saw 5
# Skipping line 6415: expected 4 fields, saw 6
# Skipping line 6416: expected 4 fields, saw 5
# Skipping line 6623: expected 4 fields, saw 5
# Skipping line 6624: expected 4 fields, saw 5
# Skipping line 7171: expected 4 fields, saw 6
# Skipping line 7220: expected 4 fields, saw 5
# ...

# %%
with open('../data/raw/CountryProductResidueData2023.txt', 'r') as f:
    first_lines = [next(f) for _ in range(3)]
for line in first_lines:
    print(repr(line))
# Out:
# '"Year"\t"Country"\t"ProdCode"\t"ProdName"\t"ResName"\t"Spls."\t"Spls%"\t"Pos."\t"Pos%"\t"Vio."\t"Vio%"\t"Trace."\t"Mean"\t"Minimum"\t"Median"\t"90th"\t"Maximum"\n'
# '"2023"\t"Afghanistan"\t"20A10"\t"Raisins (Dried Grapes)  (Berry) "\t"2,3,5,6-TETRACHLOROANILINE"\t2\t100.00\t0\t0.00\t0\t0.00\t0\t"0.000000"\t"0."\t"0."\t"0."\t"0."\n'
# '"2023"\t"Afghanistan"\t"20A10"\t"Raisins (Dried Grapes)  (Berry) "\t"2,4,5-T METHYL ESTER"\t2\t100.00\t0\t0.00\t0\t0.00\t0\t"0.000000"\t"0."\t"0."\t"0."\t"0."\n'

# %%
df = pd.read_csv('../data/raw/CountryProductResidueData2023.txt', 
                  sep='\t', 
                  quotechar='"')
df.shape
# Out:
# (803402, 17)
